# %% [markdown]
# <a href="https://colab.research.google.com/github/willdevsp/fiap-tech-challenge-pos-tech-data-analytics/blob/main/Producao_Uvas_EstadosBR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas requests beautifulsoup4

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.embrapa.br/uva-e-vinho/cadastro-viticola-nacional"

# %%
Dados_url = requests.get(url)
Dados_tabela = BeautifulSoup(response.content, 'html.parser')

# %%
Dados_tabela  = soup.find('table')

# %%
dados_prod = pd.read_html(str(Dados_tabela ))[0]

# %%
dados_prod = dados_prod.drop(index=0)

# %%
dados_prod
# Out:
#           Abrangência  Área (ha) Produção (t)
# 1   Rio Grande do Sul     46.970      902.336
# 2           São Paulo      8.436      164.016
# 3          Pernambuco      8.256      404.127
# 4              Paraná      4.000       56.912
# 5      Santa Catarina      3.849       57.681
# 6               Bahia      2.069       65.555
# 7        Minas Gerais      1.350       20.137
# 8      Espírito Santo    196.000        3.052
# 9             Paraíba    110.000        2.200
# 10              Goiás    108.000        2.310
# 11   Distrito Federal     57.000        1.303
